# %%
# 필요한 라이브러리를 먼저 설치해야 합니다.
# 터미널 또는 명령 프롬프트에서: pip install requests python-dotenv
import requests
import io
import zipfile
import re
import os
import csv
from datetime import datetime
from dotenv import load_dotenv

# .env 파일에서 환경 변수를 로드합니다.
# 이 스크립트와 같은 폴더에 .env 파일이 없다면 주석 처리해도 됩니다.
# load_dotenv()

# DART API 키를 환경 변수에서 가져옵니다.
# .env 파일이 없다면 DART_API_KEY = "여기에_API_키_입력" 과 같이 직접 설정할 수 있습니다.
DART_API_KEY = os.environ.get('OPEN_DART_API')

# 분석할 회사 목록
companys = {
            '삼성전자': '005930', 'SK하이닉스': '000660', 'LG에너지솔루션': '373220', '삼성바이오로직스': '207940', 'KB금융': '105560', 
            '삼성전자우': '005935', '현대차': '005380', '기아': '000270', 'NAVER': '035420', '셀트리온': '068270', '두산에너빌리티': '034020', '한화에어로스페이스': '012450', 
            'HD현대중공업': '329180', '신한지주': '055550', '삼성물산': '028260', '현대모비스': '012330', '하나금융지주': '086790', '카카오': '035720', '삼성생명': '032830', 
            'HMM': '011200', 'POSCO홀딩스': '005490', '한국전력': '015760', '한화오션': '042660', 'SK스퀘어': '402340', 'HD한국조선해양': '009540', '삼성화재': '000810', 
            '메리츠금융지주': '138040', '현대로템': '064350', 'LG화학': '051910', '우리금융지주': '316140', '포스코인터내셔널': '047050',
            'SK이노베이션': '096770', '고려아연': '010130', '크래프톤': '259960', '기업은행': '024110', 'KT&G': '033780', 'HD현대일렉트릭': '267260', 'SK': '034730',
            '삼성중공업': '010140', '카카오뱅크': '323410', 'KT': '030200', '삼성SDI': '006400', '삼성에스디에스': '018260', 'LG': '003550', 'LIG넥스원': '079550', 
            '미래에셋증권': '006800', 'LG전자': '066570', 'SK텔레콤': '017670', '하이브': '352820', '삼양식품': '003230', '포스코퓨처엠': '003670', 'HD현대': '267250', 
            # '카카오페이': '377300', '현대글로비스': '086280', '삼성전기': '009150', '한화시스템': '272210', 'DB손해보험': '005830', '두산': '000150', '대한항공': '003490', 
            # '효성중공업': '298040', '한미반도체': '042700', '유한양행': '000100', '한국금융지주': '071050', 
            # 'HD현대마린솔루션': '443060', '한국항공우주': '047810', '한진칼': '180640', '현대건설': '000720', 'LS ELECTRIC': '010120', 'LG씨엔에스': '064400', '아모레퍼시픽': '090430', 
            # 'SK바이오팜': '326030', '코웨이': '021240', 'NH투자증권': '005940', 'HD현대미포': '010620', 'S-Oil': '010950', '한화': '000880', '삼성증권': '016360', '삼성카드': '029780', 
            # 'LG유플러스': '032640', '에이피알': '278470', '키움증권': '039490', '한화솔루션': '009830', 'LS': '006260', '현대차2우B': '005387', '맥쿼리인프라': '088980', 
            # '한국타이어앤테크놀로지': '161390', '두산밥캣': '241560', '넷마블': '251270', 'LG생활건강': '051900', 'JB금융지주': '175330', 'BNK금융지주': '138930', 
            # '삼성E&A': '028050', 'GS': '078930', '오리온': '271560', '현대제철': '004020', 'CJ': '001040', 'LG디스플레이': '034220', '현대오토에버': '307950', '엔씨소프트': '036570', 
            # '강원랜드': '035250', '한국가스공사': '036460', '이수페타시스': '007660', '두산로보틱스': '454910'
            }

# -----------------------------------------------------------------------------
# 1단계: 지정된 기간의 모든 사업보고서 목록 조회
# -----------------------------------------------------------------------------
def get_all_business_reports(api_key, corp_code, start_year, end_year):
    """지정한 기업의 특정 기간 내 모든 사업보고서(정기보고서) 및 관련 정정보고서 목록을 조회하여 반환합니다."""
    print(f"1단계: {corp_code} 기업의 {start_year}년~{end_year}년 사업보고서 관련 목록 조회를 시작합니다.")
    list_url = "https://opendart.fss.or.kr/api/list.json"
    params = {
        'crtfc_key': api_key,
        'corp_code': corp_code,
        'bgn_de': f'{start_year}0101',
        'end_de': f'{end_year}1231',
        'pblntf_ty': 'A',
        'pblntf_detail_ty': 'A001', # 사업보고서
        'page_no': '1',
        'page_count': '100'
    }
    try:
        res = requests.get(list_url, params=params)
        res.raise_for_status()
        data = res.json()
        if data.get('status') != '000':
            print(f"API 오류: {data.get('message')}")
            return []
        if not data.get('list'):
            print("조회된 사업보고서가 없습니다.")
            return []
        
        reports = [{'rcept_no': item.get('rcept_no'), 'report_nm': item.get('report_nm'), 'rcept_dt': item.get('rcept_dt')} for item in data.get('list', [])]
        # API 결과가 기본적으로 시간순이므로 reverse 하지 않아도 최신순으로 정렬됩니다.
        print(f"성공! 총 {len(reports)}개의 관련 보고서를 찾았습니다.")
        return reports
    except Exception as e:
        print(f"1단계 오류: {e}")
        return []

# -----------------------------------------------------------------------------
# 2단계: 접수번호를 이용해 공시서류 원본 파일(XML) 요청
# -----------------------------------------------------------------------------
def get_report_xml(api_key, rcept_no):
    """접수번호를 사용하여 공시서류 원본 파일(ZIP)을 요청하고, XML 내용을 반환합니다."""
    if not rcept_no: return None
    print(f"\n2단계: 접수번호 {rcept_no}의 공시서류 원본 파일 조회를 시작합니다.")
    document_url = "https://opendart.fss.or.kr/api/document.xml"
    params = {'crtfc_key': api_key, 'rcept_no': rcept_no}
    try:
        res = requests.get(document_url, params=params)
        res.raise_for_status()
        print("성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.")
        
        with zipfile.ZipFile(io.BytesIO(res.content)) as zf:
            xml_file_name = next((f for f in zf.namelist() if f.endswith('.xml')), None)
            if not xml_file_name:
                print("ZIP 파일 내에서 XML 파일을 찾을 수 없습니다."); return None
            
            with zf.open(xml_file_name) as xml_file:
                content_bytes = xml_file.read()
                try:
                    return content_bytes.decode('utf-8-sig')
                except UnicodeDecodeError:
                    return content_bytes.decode('cp949', errors='ignore')
    except Exception as e:
        print(f"2단계 처리 중 예외가 발생했습니다: {e}"); return None

# -----------------------------------------------------------------------------
# 3단계: XML에서 모든 텍스트 추출 및 정리
# -----------------------------------------------------------------------------
def get_full_text_from_xml(xml_content):
    """XML/HTML 태그를 모두 제거하고 전체 텍스트를 정리하여 반환합니다."""
    print("3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.")
    if not xml_content: return ""
    text = re.sub(r'<[^>]+>', ' ', xml_content)
    text = re.sub(r'&nbsp;', ' ', text); text = re.sub(r'&gt;', '>', text); text = re.sub(r'&lt;', '<', text); text = re.sub(r'&amp;', '&', text)
    text = re.sub(r'(\s*\n\s*)+', '\n', text).strip()
    text = re.sub(r'\s{2,}', ' ', text)
    print("성공! 보고서 전체 텍스트를 정리했습니다.")
    return text

# -----------------------------------------------------------------------------
# 4단계: 보고서명 또는 접수일자에서 연도 추출
# -----------------------------------------------------------------------------
def extract_year(report_name, reception_date):
    """보고서명에서 연도를 우선 추출하고, 실패 시 접수일자에서 연도를 추출합니다."""
    # 정규표현식을 사용하여 보고서명에서 (YYYY.MM) 형식의 사업연도를 찾습니다.
    # 예: 사업보고서 (2023.12) -> 2023
    match = re.search(r'\((\d{4})', report_name)
    if match:
        return match.group(1)
    
    # 위에서 못찾으면, 접수일자(YYYYMMDD)에서 연도를 가져와 -1을 합니다. 
    # (보통 2024년 3월에 2023년도 사업보고서를 제출하기 때문)
    if reception_date:
        try:
            return str(int(reception_date[:4]) - 1)
        except (ValueError, TypeError):
            return "N/A" # 변환 실패 시
            
    return "N/A" # 연도를 찾을 수 없는 경우

# -----------------------------------------------------------------------------
# 5단계: 추출된 모든 보고서 내용을 하나의 CSV 파일로 저장
# -----------------------------------------------------------------------------
def save_combined_csv(reports_data, filename):
    """여러 보고서 데이터를 하나의 CSV 파일로 저장합니다."""
    print(f"\n5단계: 통합 CSV 저장을 시작합니다. 파일명: '{filename}'")
    try:
        with open(filename, 'w', newline='', encoding='utf-8-sig') as csvfile:
            writer = csv.writer(csvfile)
            writer.writerow(['년도', '회사명', '텍스트 미리보기'])
            for report in reports_data:
                writer.writerow([report['year'], report['name'], report['content']])
        
        print(f"성공! 통합 CSV '{filename}' 파일 저장을 완료했습니다.")
    except Exception as e:
        print(f"오류: 통합 CSV 파일 저장 중 문제가 발생했습니다. ({filename})")
        print(f"상세 오류: {e}")

# -----------------------------------------------------------------------------
# 메인 실행 부분
# -----------------------------------------------------------------------------
start_year,end_year=2022,2024

if __name__ == "__main__":
    if not DART_API_KEY:
        print("오류: DART API 키가 설정되지 않았습니다. .env 파일을 확인하거나 코드에 직접 입력해주세요.")
    else:
        output_folder = "사업보고서_CSV_통합"
        os.makedirs(output_folder, exist_ok=True)
        print(f"결과가 ./{output_folder}/ 폴더에 저장됩니다.")
        
        start_year,end_year=2022,2024
        print(f"조회 기간: {start_year}년 1월 1일 ~ {end_year}년 12월 31일")

        all_companies_reports = []

        for name, code in companys.items():
            print("\n" + "="*80)
            print(f"[{name}({code})] 기업의 보고서 처리를 시작합니다.")
            print("="*80)
            
            all_reports_meta = get_all_business_reports(DART_API_KEY, code, start_year, end_year)

            if not all_reports_meta:
                print(f"[{name}] 처리할 보고서가 없어 다음 기업으로 넘어갑니다.")
                continue

            # --- [핵심 수정] 연도별로 최종 보고서만 선택하는 로직 ---
            final_reports_to_process = {}
            for report_meta in all_reports_meta:
                year = extract_year(report_meta['report_nm'], report_meta['rcept_dt'])
                if year != "N/A":
                    # 딕셔너리에 연도를 key로 하여 보고서 정보를 저장합니다.
                    # 같은 연도의 보고서가 여러 개 있으면, 나중에 나온 것(최신)으로 덮어쓰게 됩니다.
                    final_reports_to_process[year] = report_meta
            
            print(f"\n총 {len(final_reports_to_process)}개의 최종 사업보고서를 처리합니다: {sorted(final_reports_to_process.keys())}년도")
            # ---------------------------------------------------------

            for year, report_meta in sorted(final_reports_to_process.items()):
                print("\n" + "-"*70)
                print(f"처리 대상: {year}년도 사업보고서 ({report_meta['report_nm']}, 접수번호: {report_meta['rcept_no']})")
                
                report_xml_content = get_report_xml(DART_API_KEY, report_meta['rcept_no'])
                
                if report_xml_content:
                    full_report_text = get_full_text_from_xml(report_xml_content)
                    
                    if full_report_text:
                        all_companies_reports.append({
                            'year': year,
                            'name': name,
                            'content': full_report_text
                        })
                    else:
                        print("보고서 내용이 비어있어 처리를 건너뜁니다.")
        
        if all_companies_reports:
            final_csv_filename = os.path.join(output_folder, f"통합_사업보고서 ({start_year}-{end_year}).csv")
            save_combined_csv(all_companies_reports, final_csv_filename)
        else:
            print("\n저장할 보고서 내용이 없어 통합 CSV 파일을 생성하지 않았습니다.")

        print("\n\n모든 기업의 보고서 처리를 완료했습니다.")
# Out:
# 결과가 ./사업보고서_CSV_통합/ 폴더에 저장됩니다.
# 조회 기간: 2022년 1월 1일 ~ 2024년 12월 31일
#
# ================================================================================
# [삼성전자(005930)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 005930 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 12개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220308000798)
#
# 2단계: 접수번호 20220308000798의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220516001751)
#
# 2단계: 접수번호 20220516001751의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230515002335)
#
# 2단계: 접수번호 20230515002335의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240516001421)
#
# 2단계: 접수번호 20240516001421의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [SK하이닉스(000660)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 000660 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 12개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220322000590)
#
# 2단계: 접수번호 20220322000590의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220516001502)
#
# 2단계: 접수번호 20220516001502의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230515001677)
#
# 2단계: 접수번호 20230515001677의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240516001638)
#
# 2단계: 접수번호 20240516001638의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [LG에너지솔루션(373220)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 373220 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 12개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220315001026)
#
# 2단계: 접수번호 20220315001026의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220516001898)
#
# 2단계: 접수번호 20220516001898의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230515002279)
#
# 2단계: 접수번호 20230515002279의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240514000898)
#
# 2단계: 접수번호 20240514000898의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [삼성바이오로직스(207940)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 207940 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 12개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220321000862)
#
# 2단계: 접수번호 20220321000862의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220516002080)
#
# 2단계: 접수번호 20220516002080의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230515002481)
#
# 2단계: 접수번호 20230515002481의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240516001936)
#
# 2단계: 접수번호 20240516001936의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [KB금융(105560)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 105560 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 22개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220317001083)
#
# 2단계: 접수번호 20220317001083의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220516002493)
#
# 2단계: 접수번호 20220516002493의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230515002541)
#
# 2단계: 접수번호 20230515002541의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240516002265)
#
# 2단계: 접수번호 20240516002265의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [삼성전자우(005935)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 005935 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# API 오류: 등록된 종목코드 또는 고유번호가 아닙니다.
# [삼성전자우] 처리할 보고서가 없어 다음 기업으로 넘어갑니다.
#
# ================================================================================
# [현대차(005380)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 005380 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 21개의 관련 보고서를 찾았습니다.
#
# 총 11개의 최종 사업보고서를 처리합니다: ['2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2014년도 사업보고서 ([기재정정]사업보고서 (2014.12), 접수번호: 20220217000891)
#
# 2단계: 접수번호 20220217000891의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2015년도 사업보고서 ([기재정정]사업보고서 (2015.12), 접수번호: 20220217000915)
#
# 2단계: 접수번호 20220217000915의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2016년도 사업보고서 ([기재정정]사업보고서 (2016.12), 접수번호: 20220217000946)
#
# 2단계: 접수번호 20220217000946의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2017년도 사업보고서 ([기재정정]사업보고서 (2017.12), 접수번호: 20220217000967)
#
# 2단계: 접수번호 20220217000967의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2018년도 사업보고서 ([기재정정]사업보고서 (2018.12), 접수번호: 20220217000981)
#
# 2단계: 접수번호 20220217000981의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2019년도 사업보고서 ([기재정정]사업보고서 (2019.12), 접수번호: 20220217001012)
#
# 2단계: 접수번호 20220217001012의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2020년도 사업보고서 ([기재정정]사업보고서 (2020.12), 접수번호: 20220217001036)
#
# 2단계: 접수번호 20220217001036의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220316001052)
#
# 2단계: 접수번호 20220316001052의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220516001998)
#
# 2단계: 접수번호 20220516001998의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230515002403)
#
# 2단계: 접수번호 20230515002403의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240516001860)
#
# 2단계: 접수번호 20240516001860의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [기아(000270)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 000270 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 13개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220321000650)
#
# 2단계: 접수번호 20220321000650의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220516002405)
#
# 2단계: 접수번호 20220516002405의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230515002201)
#
# 2단계: 접수번호 20230515002201의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240516001819)
#
# 2단계: 접수번호 20240516001819의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [NAVER(035420)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 035420 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 12개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220304000687)
#
# 2단계: 접수번호 20220304000687의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220513001543)
#
# 2단계: 접수번호 20220513001543의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230512001100)
#
# 2단계: 접수번호 20230512001100의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240516001974)
#
# 2단계: 접수번호 20240516001974의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [셀트리온(068270)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 068270 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 19개의 관련 보고서를 찾았습니다.
#
# 총 9개의 최종 사업보고서를 처리합니다: ['2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2016년도 사업보고서 ([기재정정]사업보고서 (2016.12), 접수번호: 20220512000841)
#
# 2단계: 접수번호 20220512000841의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2017년도 사업보고서 ([기재정정]사업보고서 (2017.12), 접수번호: 20220512000845)
#
# 2단계: 접수번호 20220512000845의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2018년도 사업보고서 ([기재정정]사업보고서 (2018.12), 접수번호: 20220512000849)
#
# 2단계: 접수번호 20220512000849의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2019년도 사업보고서 ([기재정정]사업보고서 (2019.12), 접수번호: 20220512000850)
#
# 2단계: 접수번호 20220512000850의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2020년도 사업보고서 ([기재정정]사업보고서 (2020.12), 접수번호: 20220512000852)
#
# 2단계: 접수번호 20220512000852의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220308000956)
#
# 2단계: 접수번호 20220308000956의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220516001445)
#
# 2단계: 접수번호 20220516001445의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230512001099)
#
# 2단계: 접수번호 20230512001099의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240516001214)
#
# 2단계: 접수번호 20240516001214의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [두산에너빌리티(034020)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 034020 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 20개의 관련 보고서를 찾았습니다.
#
# 총 8개의 최종 사업보고서를 처리합니다: ['2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2017년도 사업보고서 ([기재정정]사업보고서 (2017.12), 접수번호: 20240327001228)
#
# 2단계: 접수번호 20240327001228의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2018년도 사업보고서 ([기재정정]사업보고서 (2018.12), 접수번호: 20240327001230)
#
# 2단계: 접수번호 20240327001230의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2019년도 사업보고서 ([기재정정]사업보고서 (2019.12), 접수번호: 20240327001231)
#
# 2단계: 접수번호 20240327001231의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2020년도 사업보고서 ([기재정정]사업보고서 (2020.12), 접수번호: 20240327001232)
#
# 2단계: 접수번호 20240327001232의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220322000017)
#
# 2단계: 접수번호 20220322000017의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220513001669)
#
# 2단계: 접수번호 20220513001669의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230515002122)
#
# 2단계: 접수번호 20230515002122의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240516002258)
#
# 2단계: 접수번호 20240516002258의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [한화에어로스페이스(012450)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 012450 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 15개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220318000602)
#
# 2단계: 접수번호 20220318000602의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220516000359)
#
# 2단계: 접수번호 20220516000359의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230512001392)
#
# 2단계: 접수번호 20230512001392의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240514000801)
#
# 2단계: 접수번호 20240514000801의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [HD현대중공업(329180)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 329180 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 12개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220314000704)
#
# 2단계: 접수번호 20220314000704의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220516002360)
#
# 2단계: 접수번호 20220516002360의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230515002433)
#
# 2단계: 접수번호 20230515002433의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240516000877)
#
# 2단계: 접수번호 20240516000877의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [신한지주(055550)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 055550 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 13개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220316000748)
#
# 2단계: 접수번호 20220316000748의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220516002487)
#
# 2단계: 접수번호 20220516002487의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230515002373)
#
# 2단계: 접수번호 20230515002373의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240516001651)
#
# 2단계: 접수번호 20240516001651의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [삼성물산(028260)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 028260 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 14개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220310000790)
#
# 2단계: 접수번호 20220310000790의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220516002225)
#
# 2단계: 접수번호 20220516002225의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230515002292)
#
# 2단계: 접수번호 20230515002292의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240516001343)
#
# 2단계: 접수번호 20240516001343의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [현대모비스(012330)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 012330 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 16개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220315000823)
#
# 2단계: 접수번호 20220315000823의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220516001449)
#
# 2단계: 접수번호 20220516001449의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230515001771)
#
# 2단계: 접수번호 20230515001771의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240516001455)
#
# 2단계: 접수번호 20240516001455의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [하나금융지주(086790)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 086790 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 16개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220317001011)
#
# 2단계: 접수번호 20220317001011의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220516002206)
#
# 2단계: 접수번호 20220516002206의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230515002498)
#
# 2단계: 접수번호 20230515002498의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240516001763)
#
# 2단계: 접수번호 20240516001763의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [카카오(035720)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 035720 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 25개의 관련 보고서를 찾았습니다.
#
# 총 5개의 최종 사업보고서를 처리합니다: ['2020', '2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2020년도 사업보고서 ([기재정정]사업보고서 (2020.12), 접수번호: 20240320000376)
#
# 2단계: 접수번호 20240320000376의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220321001331)
#
# 2단계: 접수번호 20220321001331의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220516002455)
#
# 2단계: 접수번호 20220516002455의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230515002409)
#
# 2단계: 접수번호 20230515002409의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240516000225)
#
# 2단계: 접수번호 20240516000225의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [삼성생명(032830)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 032830 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 21개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220308000939)
#
# 2단계: 접수번호 20220308000939의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220516002463)
#
# 2단계: 접수번호 20220516002463의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230515002761)
#
# 2단계: 접수번호 20230515002761의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240516001688)
#
# 2단계: 접수번호 20240516001688의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [HMM(011200)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 011200 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 16개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220321001124)
#
# 2단계: 접수번호 20220321001124의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220513000332)
#
# 2단계: 접수번호 20220513000332의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230515001036)
#
# 2단계: 접수번호 20230515001036의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240514000756)
#
# 2단계: 접수번호 20240514000756의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [POSCO홀딩스(005490)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 005490 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 14개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220310001226)
#
# 2단계: 접수번호 20220310001226의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220516002202)
#
# 2단계: 접수번호 20220516002202의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230515001841)
#
# 2단계: 접수번호 20230515001841의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240516002077)
#
# 2단계: 접수번호 20240516002077의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [한국전력(015760)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 015760 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 17개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220321001499)
#
# 2단계: 접수번호 20220321001499의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220516002453)
#
# 2단계: 접수번호 20220516002453의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230515002886)
#
# 2단계: 접수번호 20230515002886의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240516002201)
#
# 2단계: 접수번호 20240516002201의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [한화오션(042660)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 042660 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 15개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220314001167)
#
# 2단계: 접수번호 20220314001167의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220516002442)
#
# 2단계: 접수번호 20220516002442의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230515002059)
#
# 2단계: 접수번호 20230515002059의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240513000844)
#
# 2단계: 접수번호 20240513000844의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [SK스퀘어(402340)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 402340 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 17개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220317000691)
#
# 2단계: 접수번호 20220317000691의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220516000679)
#
# 2단계: 접수번호 20220516000679의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230515001482)
#
# 2단계: 접수번호 20230515001482의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240516001564)
#
# 2단계: 접수번호 20240516001564의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [HD한국조선해양(009540)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 009540 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 12개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220314000893)
#
# 2단계: 접수번호 20220314000893의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220516002273)
#
# 2단계: 접수번호 20220516002273의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230515002532)
#
# 2단계: 접수번호 20230515002532의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240516000606)
#
# 2단계: 접수번호 20240516000606의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [삼성화재(000810)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 000810 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 19개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220310001159)
#
# 2단계: 접수번호 20220310001159의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220516002201)
#
# 2단계: 접수번호 20220516002201의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230515002508)
#
# 2단계: 접수번호 20230515002508의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240516001321)
#
# 2단계: 접수번호 20240516001321의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [메리츠금융지주(138040)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 138040 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 32개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220316001217)
#
# 2단계: 접수번호 20220316001217의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220516002041)
#
# 2단계: 접수번호 20220516002041의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230515002396)
#
# 2단계: 접수번호 20230515002396의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240516001693)
#
# 2단계: 접수번호 20240516001693의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [현대로템(064350)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 064350 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 12개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220315000952)
#
# 2단계: 접수번호 20220315000952의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220516000749)
#
# 2단계: 접수번호 20220516000749의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230515001087)
#
# 2단계: 접수번호 20230515001087의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240516001877)
#
# 2단계: 접수번호 20240516001877의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [LG화학(051910)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 051910 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 13개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220315001036)
#
# 2단계: 접수번호 20220315001036의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220516001879)
#
# 2단계: 접수번호 20220516001879의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230515002419)
#
# 2단계: 접수번호 20230515002419의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240514000571)
#
# 2단계: 접수번호 20240514000571의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [우리금융지주(316140)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 316140 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 13개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220317001124)
#
# 2단계: 접수번호 20220317001124의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220516002422)
#
# 2단계: 접수번호 20220516002422의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230515002692)
#
# 2단계: 접수번호 20230515002692의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240516001742)
#
# 2단계: 접수번호 20240516001742의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [포스코인터내셔널(047050)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 047050 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 14개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220311001166)
#
# 2단계: 접수번호 20220311001166의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220513000936)
#
# 2단계: 접수번호 20220513000936의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230515001613)
#
# 2단계: 접수번호 20230515001613의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240516002122)
#
# 2단계: 접수번호 20240516002122의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [SK이노베이션(096770)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 096770 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 12개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220323000978)
#
# 2단계: 접수번호 20220323000978의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220513001363)
#
# ...
#
# 2단계: 접수번호 20230515002418의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240516001750)
#
# 2단계: 접수번호 20240516001750의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [삼성SDI(006400)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 006400 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 13개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220308000915)
#
# 2단계: 접수번호 20220308000915의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220516001936)
#
# 2단계: 접수번호 20220516001936의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230515002370)
#
# 2단계: 접수번호 20230515002370의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240516002154)
#
# 2단계: 접수번호 20240516002154의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [삼성에스디에스(018260)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 018260 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 13개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220308000737)
#
# 2단계: 접수번호 20220308000737의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220516001830)
#
# 2단계: 접수번호 20220516001830의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230515001868)
#
# 2단계: 접수번호 20230515001868의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240516001677)
#
# 2단계: 접수번호 20240516001677의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [LG(003550)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 003550 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 12개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220321001237)
#
# 2단계: 접수번호 20220321001237의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220516002276)
#
# 2단계: 접수번호 20220516002276의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230515001874)
#
# 2단계: 접수번호 20230515001874의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240516001596)
#
# 2단계: 접수번호 20240516001596의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [LIG넥스원(079550)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 079550 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 14개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220318000012)
#
# 2단계: 접수번호 20220318000012의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220513000473)
#
# 2단계: 접수번호 20220513000473의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230515000336)
#
# 2단계: 접수번호 20230515000336의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240516000174)
#
# 2단계: 접수번호 20240516000174의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [미래에셋증권(006800)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 006800 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 12개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220316001023)
#
# 2단계: 접수번호 20220316001023의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220516002062)
#
# 2단계: 접수번호 20220516002062의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230515002014)
#
# 2단계: 접수번호 20230515002014의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240516001912)
#
# 2단계: 접수번호 20240516001912의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [LG전자(066570)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 066570 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 13개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220316000440)
#
# 2단계: 접수번호 20220316000440의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220516001009)
#
# 2단계: 접수번호 20220516001009의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230515001288)
#
# 2단계: 접수번호 20230515001288의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240516000752)
#
# 2단계: 접수번호 20240516000752의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [SK텔레콤(017670)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 017670 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 13개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220316000250)
#
# 2단계: 접수번호 20220316000250의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220513001457)
#
# 2단계: 접수번호 20220513001457의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230512000710)
#
# 2단계: 접수번호 20230512000710의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240516000420)
#
# 2단계: 접수번호 20240516000420의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [하이브(352820)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 352820 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 16개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220322000653)
#
# 2단계: 접수번호 20220322000653의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220513001697)
#
# 2단계: 접수번호 20220513001697의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230515001896)
#
# 2단계: 접수번호 20230515001896의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240516001604)
#
# 2단계: 접수번호 20240516001604의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [삼양식품(003230)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 003230 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 12개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220315001195)
#
# 2단계: 접수번호 20220315001195의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220516002536)
#
# 2단계: 접수번호 20220516002536의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230515002256)
#
# 2단계: 접수번호 20230515002256의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240516001968)
#
# 2단계: 접수번호 20240516001968의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [포스코퓨처엠(003670)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 003670 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 15개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220311001089)
#
# 2단계: 접수번호 20220311001089의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220516001003)
#
# 2단계: 접수번호 20220516001003의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230515002518)
#
# 2단계: 접수번호 20230515002518의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240514001459)
#
# 2단계: 접수번호 20240514001459의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ================================================================================
# [HD현대(267250)] 기업의 보고서 처리를 시작합니다.
# ================================================================================
# 1단계: 267250 기업의 2022년~2024년 사업보고서 관련 목록 조회를 시작합니다.
# 성공! 총 15개의 관련 보고서를 찾았습니다.
#
# 총 4개의 최종 사업보고서를 처리합니다: ['2021', '2022', '2023', '2024']년도
#
# ----------------------------------------------------------------------
# 처리 대상: 2021년도 사업보고서 (사업보고서 (2021.12), 접수번호: 20220318000982)
#
# 2단계: 접수번호 20220318000982의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2022년도 사업보고서 (분기보고서 (2022.03), 접수번호: 20220516002370)
#
# 2단계: 접수번호 20220516002370의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2023년도 사업보고서 (분기보고서 (2023.03), 접수번호: 20230515002586)
#
# 2단계: 접수번호 20230515002586의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# ----------------------------------------------------------------------
# 처리 대상: 2024년도 사업보고서 (분기보고서 (2024.03), 접수번호: 20240516001843)
#
# 2단계: 접수번호 20240516001843의 공시서류 원본 파일 조회를 시작합니다.
# 성공! 공시서류 원본 파일(ZIP)을 내려받았습니다.
# 3단계: 보고서 전체 내용에서 텍스트 추출을 시작합니다.
# 성공! 보고서 전체 텍스트를 정리했습니다.
#
# 5단계: 통합 CSV 저장을 시작합니다. 파일명: '사업보고서_CSV_통합\통합_사업보고서 (2022-2024).csv'
# 성공! 통합 CSV '사업보고서_CSV_통합\통합_사업보고서 (2022-2024).csv' 파일 저장을 완료했습니다.
#
#
# 모든 기업의 보고서 처리를 완료했습니다.

# %%
import pandas as pd
import os

folder = "사업보고서_CSV_통합"
file = "통합_사업보고서 (2022-2024).csv"
file_path = os.path.join(folder, file)

target_company = '삼양식품'
year = 2022

df = pd.read_csv(file_path)

df['년도'] = pd.to_numeric(df['년도'])
            
target_report = df[(df['회사명'] == target_company) & (df['년도'] == year)]

report_content = target_report['텍스트 미리보기'].iloc[0]
    
print(report_content[100000:110000])
# Out:
# 권 미상환 잔액
# (기준일 :
# 2022년 03월 31일
# )
# (단위 : 원)
# 잔여만기
# 10일 이하
# 10일초과&cr;30일이하
# 30일초과&cr;90일이하
# 90일초과&cr;180일이하
# 180일초과&cr;1년이하
# 1년초과&cr;2년이하
# 2년초과&cr;3년이하
# 3년 초과
# 합 계
# 미상환 잔액
# 공모
# -
# -
# -
# -
# -
# -
# -
# -
# -
# 사모
# -
# -
# -
# -
# -
# -
# -
# -
# -
# 합계
# -
# -
# -
# -
# -
# -
# -
# -
# -
# 단기사채 미상환 잔액
# (기준일 :
# 2022년 03월 31일
# )
# (단위 : 원)
# 잔여만기
# 10일 이하
# 10일초과&cr;30일이하
# 30일초과&cr;90일이하
# 90일초과&cr;180일이하
# 180일초과&cr;1년이하
# 합 계
# 발행 한도
# 잔여 한도
# 미상환 잔액
# 공모
# -
# -
# -
# -
# -
# -
# -
# -
# 사모
# -
# -
# -
# -
# -
# -
# -
# -
# 합계
# -
# -
# -
# -
# -
# -
# -
# -
# 회사채 미상환 잔액
# (기준일 :
# 2022년 03월 31일
# )
# (단위 : 원)
# 잔여만기
# 1년 이하
# 1년초과&cr;2년이하
# 2년초과&cr;3년이하
# 3년초과&cr;4년이하
# 4년초과&cr;5년이하
# 5년초과&cr;10년이하
# 10년초과
# 합 계
# 미상환 잔액
# 공모
# -
# -
# 75,000,000,000
# -
# -
# -
# -
# 75,000,000,000
# 사모
# -
# -
# -
# -
# -
# -
# -
# -
# 합계
# -
# -
# 75,000,000,000
# -
# -
# -
# -
# 75,000,000,000
# 신종자본증권 미상환 잔액
# (기준일 :
# 2022년 03월 31일
# )
# (단위 : 원)
# 잔여만기
# 1년 이하
# 1년초과&cr;5년이하
# 5년초과&cr;10년이하
# 10년초과&cr;15년이하
# 15년초과&cr;20년이하
# 20년초과&cr;30년이하
# 30년초과
# 합 계
# 미상환 잔액
# 공모
# -
# -
# -
# -
# -
# -
# -
# -
# 사모
# -
# -
# -
# -
# -
# -
# -
# -
# 합계
# -
# -
# -
# -
# -
# -
# -
# -
# 조건부자본증권 미상환 잔액
# (기준일 :
# 2022년 03월 31일
# )
# (단위 : 원)
# 잔여만기
# 1년 이하
# 1년초과&cr;2년이하
# 2년초과&cr;3년이하
# 3년초과&cr;4년이하
# 4년초과&cr;5년이하
# 5년초과&cr;10년이하
# 10년초과&cr;20년이하
# 20년초과&cr;30년이하
# 30년초과
# 합 계
# 미상환 잔액
# 공모
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# 사모
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# 합계
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# 나. 사채관리계약 주요내용 및 충족여부 등
# (작성기준일 :
# 2022년 03월 31일
# )
# (단위 : 원, %)
# 채권명
# 발행일
# 만기일
# 발행액
# 사채관리&cr;계약체결일
# 사채관리회사
# 삼양식품 주식회사 &cr;제1회 무보증사채 &cr;사채관리계약
# 2021년 12월 09일
# 2024년 12월 09일
# 75,000,000,000
# 2021년 12월 03일
# 한국예탁결제원
# (이행현황기준일 :
# 2022년 03월 31일
# )
# 재무비율 유지현황
# 계약내용
# 부채비율 300% 이하로 유지
# 이행현황
# 계약조항의 재무비율을 유지함
# 담보권설정 제한현황
# 계약내용
# 사채발행 이후 지급보증 또는 "담보권"이 설정되는 채무의 합계액이 &cr;"최근 보고서"상 연결 기준 "자기자본"의 200% 미만
# 이행현황
# 계약조항을 위반하여 지급보증의무를 부담하거나담보권을 설정하지 아니함
# 자산처분 제한현황
# 계약내용
# 회계년도에 1회 또는 수회에 걸쳐 연결 자산총계의 70%(자산처분 후 1년 이내에 처분가액 등을 재원으로 취득한 자산이 있는 경우 이를 차감) 이상 처분제한
# 이행현황
# 계약조항을 위반하여 자산을 처분하지 아니함
# 지배구조변경 제한현황
# 계약내용
# 최대주주 변경 제한
# 이행현황
# 최대주주가 변경되지 아니함
# 이행상황보고서 제출현황
# 이행현황
# -
# * 이행현황기준일은 이행현황 판단 시 적용한 회계감사인의 감사의견(확인 및 의견표시)이 표명된 가장 최근의 재무제표의 작성기준일이며, 지배구조변경 제한현황은 공시서류작성기준일임.
# 7-2. 증권의 발행을 통해 조달된 자금의 사용실적
# 가. 공모자금의 사용내역
# (기준일 :
# 2022년 03월 31일
# )
# (단위 : 백만원)
# 구 분
# 회차
# 납입일
# 증권신고서 등의&cr; 자금사용 계획
# 실제 자금사용&cr; 내역
# 차이발생 사유 등
# 사용용도
# 조달금액
# 내용
# 금액
# 무보증사채
# 1
# 2021년 12월 09일
# 시설자금
# 40,000
# 시설자금
# 40,000
# -
# 무보증사채
# 1
# 2021년 12월 09일
# 운영자금
# 35,000
# 운영자금
# 25,000
# 안정성 높은 금융상품 가입 통해 자금 운용
# 나. 미사용자금의 운용내역
# (기준일 :
# 2022년 03월 31일
# )
# (단위 : 백만원)
# 종류
# 금융상품명
# 운용금액
# 계약기간
# 실투자기간
# 기타
# 행복파트너 신탁 제C-04호
# 10,000
# 2022년 03월 ~ 2022년 04월
# 좌동
# 계
# 10,000
# -
# 8. 기타 재무에 관한 사항
# 가. 재무제표 재작성 등 유의사항&cr; &cr;(1) 재무제표 재작성&cr;&cr; 해당사항 없음&cr;&cr;(2) 합병, 분할, 자산양수도, 영업양수도&cr;&cr;자산양수도 :&cr;- 양수도 내역&cr; 당사는 2020년 9월 14일 (주)삼양프루웰에게 우산동 390-5번지의 토지를 35억원에 양도하고, 우산동 390-4번지의 토지를 41억원에 양수받는 자산양수도계약을 체결하였습니다.&cr;
# 영업양수도 :&cr;- 양수도 내역&cr; 당사는 2022년 2월 28일 삼양냉동 주식회사에게 냉동식품 가공 및 판매업과 관련된 B2C 채널 일체를 양수받는 영업양수도계약을 체결하였습니다.&cr;
# 구 분
# 주 요 내 용
# 양 수 인
# 삼양식품(주)
# 양 도 인
# 삼양냉동(주)
# 영업양수도 대상
# 냉동식품 가공 및 판매업 관련 B2C 채널 등
# 이사회 결의일
# 2022년 02월 28일
# 양수도 계약완료일
# 2022년 03월 02일
# 계약금액
# 약 111 억원(부가가치세 제외)
# (3) 자산유동화와 관련한 자산매각의 회계처리 및 우발채무 등에 관한 사항&cr;&cr; 해당사항 없음&cr;&cr;(4) 기타 재무제표 이용에 유의하여야 할 사항&cr; &cr; 해당사항 없음&cr;&cr;
# 나. 대손충당금 설정현황&cr; &cr;(1) 연결회사의 당기 및 최근 2사업연도의 계정과목별 대손충당금 설정내역&cr; (단위: 백만원)
# 구분
# 계정과목
# 채권 총액
# 대손충당금
# 대손충당금&cr;설정률
# 제 62기 1분기&cr;(당기)
# 매출채권
# 69,280
# 6,958
# 10.0%
# 미수금
# 3,780
# 328
# 8.7%
# 선급금
# 268
# 120
# 44.8%
# 보증금
# 6,741
# 59
# 0.9%
# 합계
# 80,069
# 7,465
# 9.3%
# 제 61기&cr;(전기)
# 매출채권
# 59,977
# 6,777
# 11.3%
# 미수금
# 7,187
# 283
# 3.9%
# 선급금
# 269
# 120
# 44.7%
# 보증금
# 6,900
# 59
# 0.8%
# 합계
# 74,333
# 7,239
# 9.7%
# 제 60기&cr;(전전기)
# 매출채권
# 52,714
# 8,262
# 15.7%
# 미수금
# 3,398
# -
# 0.0%
# 선급금
# 138
# 120
# 86.7%
# 보증금
# 7,942
# 59
# 0.7%
# 합계
# 64,192
# 8,441
# 13.1%
# &cr;※ 당사는 新금융상품기준서(제1109호) 제정에 따라 제60기(전전기), 제61기(전기), 제62기 1분기(당기)는 대손충당금 설정방식이 기대손실모형으로 작성되었습니다.&cr;&cr;(2) 연결회사의 당기 및 최근 2사업연도의 대손충당금 변동현황&cr; (단위: 백만원)
# 구분
# 제 62 기 1분기
# 제 61 기
# 제 60 기
# 1. 기초 대손충당금 잔액합계
# 7,239
# 8,441
# 2,198
# 2. 순대손처리액(①-②±③)
# -
# -
# (2)
# ①대손처리액(상각채권액)
# -
# -
# -
# ②상각채권회수액
# -
# -
# (2)
# ③기타증감액
# -
# -
# -
# 3. 대손상각비 계상(환입)액
# 226
# (1,202)
# 6,245
# 4. 기말 대손충당금 잔액합계
# 7,465
# 7,239
# 8,441
# (3) 매출채권관련 대손충당금 설정방침(연결기준)&cr;&cr;1) 대손충당금 설정방침&cr; 재무상태표일 현재 매출채권 잔액에 대하여 과거 경험율을 추정하여 설정대상액을 계산하고 개별 손상 여부 및 담보설정여부 확인 후 확정하고 있습니다.
# &cr;2) 대손경험율 산정근거
# 과거 2개년 사업연도종료일 현재 채권 잔액에 대해 Aging계산하고 기간별 미회수율을 측정하여 예상되는 대손 추정액을 산정하고 있습니다.&cr;&cr;(4) 연결회사의 당기말 현재 경과기간별 매출채권잔액 현황
# (단위 : 백만원)
# 구 분
# 6월 이하
# 6월 초과&cr;1년 이하
# 1년 초과&cr;3년 이하
# 3년 초과
# 계
# 금&cr;액
# 일반
# 54,612
# 74
# 7,339
# -
# 62,025
# 특수관계자
# 4,402
# 185
# 2,668
# -
# 7,255
# 계
# 59,014
# 259
# 10,007
# -
# 69,280
# 구성비율
# 85.2%
# 0.4%
# 14.4%
# 0.0%
# 100.0%
# 다. 재고자산의 보유 및 실사내역 등&cr; &cr;(1) 연결회사의 당기 및 최근 2사업연도의 재고자산의 사업부문별 보유현황 &cr;
# (단위 : 백만원)
# 사업부문
# 계정과목
# 제 62 기 &cr;1분기
# 제 61 기
# 제 60 기
# 식품 제조, 판매 및&cr;골판지 제조, 판매
# 제품
# 24,832
# 18,687
# 12,877
# 상품
# 1,225
# 340
# 562
# 반제품
# 5,403
# 4,751
# 4,265
# 재공품
# 8
# 9
# -
# 원재료
# 21,527
# 18,758
# 14,815
# 기타
# 4,338
# 2,499
# 2,013
# 재고자산평가충당금
# (279)
# (269)
# (78)
# 합 계
# 57,054
# 44,776
# 34,454
# 총자산대비 재고자산 구성비율(%)&cr;[재고자산합계÷기말자산총계×100]
# 7.4
# 5.9
# 6.2
# 재고자산회전율(회수)&cr;[연환산 매출원가÷{(기초재고＋기말재고)÷2}]
# 11.4회
# 11.9회
# 14.7회
# &cr;(2) 재고자산의 실사내역 등&cr;&cr;1) 실사일자 :&cr; ㄱ. 정기실사는 12월말 기준으로 매년 1회 재고자산 실사.&cr; ㄴ. 수시실사는 매월 지정 재고 실사.&cr;&cr;2) 실사방법 :&cr; ㄱ. 전수조사 실시를 기본으로 하며, 일부 중요성이 적은 품목의 경우,&cr; Sample 조사.&cr; ㄴ. 당사 재무팀, 감사팀 및 삼일회계법인 소속의 외부감사인(12월말 재고 실사 時&cr; ) 입회 실사.&cr;&cr;3) 장기체화재고 등 현황 : 장기체화 및 재고자산의 시가가 취득원가보다 하락한 경우에는 시가를 재무상태표가액으로 하고 있으며, 당기말 현재 연결회사의 재고자산에 대한 평가내역은 다음과 같습니다.&cr;
# (단위 : 백만원)
# 계정과목
# 취득원가
# 보유금액
# 당기평가손실
# 장부가액
# 비고
# 제품
# 24,832
# 24,832
# (45)
# 24,788
# -
# 상품
# 1,225
# 1,225
# (44)
# 1,180
# -
# 반제품
# 5,403
# 5,403
# (22)
# 5,382
# -
# 재공품
# 8
# 8
# -
# 8
# -
# 원재료
# 21,527
# 21,527
# (168)
# 21,359
# -
# 기타
# 4,338
# 4,338
# -
# 4,338
# -
# 합계
# 57,333
# 57,333
# (279)
# 57,054
# -
# 라. 진행률적용 수주계약 현황 &cr;&cr;현재 당사는 수주계약 현황에 해당하는 건이 없습니다.&cr;&cr;
# 마. 공정가치평가 내역 &cr;&cr;
# 당사의 공정가치평가 내역은 'Ⅲ. 재무에 관한사항, 3. 연결재무제표 주석, 4. 금융상품 공정가치' 의 내용을 참고하시기 바랍니다.
# IV. 이사의 경영진단 및 분석의견
# &cr;당사는 기업공시서식 작성기준에 따라 분, 반기 보고서에는 '이사의 경영진단 및 분석의견'을 기재하지 않습니다.
# V. 회계감사인의 감사의견 등
# 1. 외부감사에 관한 사항
# &cr;1. 회계감사인의 명칭 및 감사의견&cr;
# &cr;삼일회계법인은 당사의 제62기 1분기(당분기) 검토를 수행하였고, 검토결과 상기 분기재무제표가 한국채택국제회계기준 제1034호(중간재무보고)에 따라 중요성의 관점에서 공정하게 표시하지 않은 사항이 발견되지 아니하였습니다. &cr; &cr;삼일회계법인은 당사의 제61기, 제60기 감사를 수행하였고, 감사의견은 모두 적정입니다.
# 사업연도
# 감사인
# 감사의견
# 강조사항 등
# 핵심감사사항
# 제62기1분기&cr;(당기)
# 삼일회계법인
# 해당사항없음
# COVID-19 대한 회사의 영향
# -
# 제61기(전기)
# 삼일회계법인
# 적정
# COVID-19 대한 회사의 영향
# 재화의 판매 관련 &cr;매출장려활동
# 제60기(전전기)
# 삼일회계법인
# 적정
# COVID-19 대한 회사의 영향
# 재화의 판매 관련 &cr;매출장려활동
# 2. 감사용역 체결현황
# 사업연도
# 감사인
# 내 용
# 감사계약내역
# 실제수행내역
# 보수
# 시간
# 보수
# 시간
# 제62기 1분기&cr;(당기)
# 삼일회계법인
# 별도 및 연결 분기 재무제표 검토
# 290
# 2,898
# 58
# 310
# 제61기(전기)
# 삼일회계법인
# 분반기, 중간, 기말, 연결 재무제표 검토 및 감사
# 257
# 2,574
# 257
# 3,265
# 제60기(전전기)
# 삼일회계법인
# 반기, 중간, 기말, 연결 재무제표 검토 및 감사
# 165
# 1,703
# 165
# 1,823
# 3. 회계감사인과의 비감사용역 계약체결 현황
# 사업연도
# 계약체결일
# 용역내용
# 용역수행기간
# 용역보수
# 비고
# 제62기 1분기&cr;(당기)
# 2022년 3월 31일
# 세무용역계약&cr;(각종 세목 경정청구)
# 2022년 5월 16일 ~2022년 5월 27일
# -
# 보수 : 경정 성공 금액× 10%,20%
# 제61기(전기)
# -
# -
# -
# -
# -
# 제60기(전전기)
# -
# -
# -
# -
# -
# 4. 재무제표 중 이해관계자의 판단에 상당한 영향을 미칠 수 있는 사항에 대해 내부감사기구가 회계감사인과 논의한 결과
# 구분
# 일자
# 참석자
# 방식
# 주요 논의 내용
# 1
# 2022년 03월 08일
# ㆍ감사위원회 : 위원 3명&cr;ㆍ회사 : 재무담당 임원 1명&cr;ㆍ감사인: 업무수행이사 외 1명
# 대면회의
# 감사에서의 유의적 발견사항, 유의적 내부통제의 미비점, &cr;감사인의 독립성, 핵심감사사항 논의, 기타강조사항 등
# 2
# 2022년 05월 12일
# ㆍ감사위원회 : 위원 3명&cr;ㆍ회사 : 내부회계 임원 외 2명&cr;ㆍ감사인: 업무수행이사 1명
# 대면회의
# 감사팀 구성, 감사투입시간과 보수, 핵심감사사항 논의 등
# 2. 내부통제에 관한 사항
# 1. 내부통제&cr;&cr;[감사 및 감사위원회가 회사의 내부통제의 유효성에 대해 감사한 결과]
# 사업연도
# 감사의 의견
# 지적사항
# 제 62기 1분기&cr;(당기)
# -
# -
# 제 61기(전기)
# 본 감사의 의견으로는 2021년 12월 31일로 종료되는 회계연도의 삼양식품(주)의 내부감시장치는 효과적으로 운영되고 있음.
# -
# 제 60기(전전기)
# 본 감사의 의견으로는 2020년 12월 31일로 종료되는 회계연도의 삼양식품(주)의 내부감시장치는 효과적으로 운영되고 있음.
# -
# &cr;※ 당사는 2021년 3월에 감사위원회를 설치하였으며, 제 61기부터는 감사위원회가 내부감사기구의 역할을 수행합니다. &cr;
# 2. 내부회계관리제도&cr;&cr;[회계감사인의 내부회계관리제도 검토 및 감사의견]
# 사업연도
# 감사인
# 검토 및 감사의견
# 지적사항
# 제 62기 1분기(당기)
# 삼일회계법인
# -
# -
# 제 61기(전기)
# 삼일회계법인
# 회사의 내부회계관리제도는 2021년 12월 31일 현재「내부회계관리제도 설계 및 운영 개념체계」에 따라 중요성의 관점에서 효과적으로 설계 및 운영되고 있습니다.
# -
# 제 60기(전전기)
# 삼일회계법인
# 당사의 내부회계관리제도 운영실태평가보고서를 검토하고 운영실태평가보고의 내용이 중요성의 관점에서 내부회계관리제도 모범규준의 규정에 따라 작성되지 않았다고 판단하게 하는 점이 발견되지 아니하였다는 의견을 표명하였습니다.
# -
# &cr;3. 내부통제구조의 평가&cr;&cr;공시대상기간에 내부회계관리제도 이외의 내부통제구조를 평가받은 사실이 없습니다.
# VI. 이사회 등 회사의 기관에 관한 사항
# 1. 이사회에 관한 사항
# 가. 이사회 구성 개요&cr;
# &cr;
# 2022년도 1분기 보고서 작성기준일 현재 당사의 이사회는 4인의 사내이사, 4인의 사외이사 총 8인의 이사로 구성되어 있으며, 상법 및 정관 30조에 의거하여 이사의 임기는 3년으로 하고 있습니다. &cr;&cr;이사회는 이사진 간 의견을 조율하고 이사회 활동을 총괄하는 역할에 적임이라고 판단되는 문용욱 사내이사를 의장으로 선임하였습니다. 이사회의 독립성과 투명성을 높이기 위해 이사회 의장은 대표이사와 분리되어 있습니다.&cr;&cr;현재 당사의 이사회 내 총 5개의 소위원회(감사위원회, 보상위원회, 사외이사후보추천위원회, ESG위원회, 경영위원회)가 설치되어 있습니다.&cr;&cr;각 이사의 주요 이력 및 업무분장은 'Ⅷ. 임원 및 직원 등에 관한 사항'을 참조하시기 바랍니다.&cr;
# 나. 중요의결사항&cr;
# 회차
# 개최일자
# 의안내용
# 가결&cr;여부
# 사내이사
# 사외이사
# 정태운
# 진종기
# 김정수
# 문용욱
# 장재성
# 김동찬
# 홍철규
# 이희수
# 정무식
# 강소엽
# (출석률:&cr;100%)
# (출석률:&cr;100%)
# (출석률:&cr;100%)
# (출석률:&cr;100%)
# (출석률:&cr;100%)
# (출석률:&cr;100%)
# (출석률:&cr;100%)
# (출석률:&cr;100%)
# (출석률:&cr;75%)
# (출석률:&cr;100%)
# 1회차
# 2022.01.25
# ㆍ 제1호 의안 : 준법지원인 선임의 건
# 가결
# 찬성
# 찬성
# 찬성
# 찬성
# 해당사항&cr;없음
# 해당사항&cr;없음
# 찬성
# 찬성
# 찬성
# 찬성
# ㆍ 제2호 의안 : 지배인 해임의 건
# 가결
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# 2회차
# 2022.02.08
# ㆍ 제1호 의안 : 내부회계관리제도 운영실태 보고의 건
# -
# 참석
# 참석
# 참석
# 참석
# 참석
# 참석
# 참석
# 참석
# ㆍ 제2호 의안 : 제61기 재무제표(별도, 연결) 승인의 건
# 가결
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# ㆍ 제3호 의안 : 현금배당(안) 결정의 건
# 가결
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# ㆍ 제4호 의안 : 자기주식 취득의 건
# 가결
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# ㆍ 제5호 의안 : 제61기 정기주주총회 소집결의의 건
# 가결
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# ㆍ 제6호 의안 : 임원 겸직 승인의 건
# 가결
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# ㆍ 제7호 의안 : 전자투표제도 도입의 건
# 가결
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# ㆍ 제8호 의안 : 영업양수도의 건
# 가결
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# ㆍ 제9호 의안 : 소위원회 활동내역 보고의 건
# -
# 참석
# 참석
# 참석
# 참석
# 참석
# 참석
# 참석
# 참석
# 3회차
# 2022.03.08
# ㆍ 제1호 의안 : 내부회계관리제도 운영실태 평가보고의 건
# -
# 참석
# 참석
# 참석
# 참석
# 참석
# 참석
# 참석
# 참석
# ㆍ 제2호 의안 : 이사회 규정 및 경영위원회 규정 변경의 건
# 가결
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# 4회차
# 2022.03.23
# ㆍ 제1호 의안 : 임원 보수 집행 위임의 건
# 가결
# 해당사항&cr;없음
# 해당사항&cr;없음
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# 불참
# 찬성
# ㆍ 제2호 의안 : 각자 대표이사 선임의 건
# 가결
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# 불참
# 찬성
# ㆍ 제3호 의안 : CSO 선임 및 관련 조직 신설의 건
# 가결
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# 불참
# 찬성
# ㆍ 제4호 의안 : 이사회 산하 위원회 위원 선임의 건
# 가결
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# 찬성
# 불참
# 찬성
# ※ 2022년 3월 23일 제61기 정기주주총회에서 장재성 대표이사 및 김동찬 사내이사를 신규선임하였으며, 진종기, 정태운 사내이사는 각각 임기만료 및 일신상의 사유로사임하였습니다.
# 다. 사외이사 및 그 변동현황
# (단위 : 명)
# 이사의 수
# 사외이사 수
# 사외이사 변동현황
# 선임
# 해임
# 중도퇴임
# 8
# 4
# -
# -
# -
# 라. 이사회 내 위원회&cr;&cr;
# (1) 이사회 내 위원회 구성현황&cr;
# 위원회명
# 구성
# 위원 성명
# 설치목적 및 권한사항
# 비고
# 감사위원회
# 사외이사 3명
# 홍철규(長), 정무식, 이희수
# 회사의 회계와 업무를 감사하고, 이사회가 위임한 사항을 처리
# -
# 보상위원회
# 사내이사 1명
# 사외이사 2명
# 문용욱(長), 정무식, 이희수
# 이사 보수의 객관성 및 투명성 확보 및 이사회 위임 사항 처리
# -
# 사외이사후보&cr; 추천위원회
# 사내이사 1명
# 사외이사 2명
# 정무식(長),
# 장재성
# , 강소엽
# 관계 법령과 정관 및 이사회 규정에 따라 회사의 사외이사 후보의 추천
# -
# ESG 위원회
# 사내이사3명
# 사외이사1명
# 김정수(長), 문용욱,
# 장재성,
# 강소엽
# 장기적으로 지속 가능한 성장을 이룰 수 있도록 회사의ESG 부문에 대한 전략 및 방향성 수립, 이와 관련한 성과평가 등 수행
# -
# 경영위원회
# 사내이사 4명
# 장재성(長), 김정수,
# 문용욱,
# 김동찬
# 업무수행의 전문성과 효율성을 높이기 위해 정관, 이사회 규정, 경영위원회 규정에 따른 사항 및 이사회가 위임한 사항 처리
# -
# (2) 위원회 활동내용&cr;&cr;
# 위원회명
# 활 동 내 역
# 사외이사
# 개최일자
# 의안내용
# 가결여부
# 홍철규&cr; (출석률:&cr; 100%)
# 정무식&cr; (출석률:&cr; 66.7%)
# 이희수&cr; (출석률:&cr; 100%)
# 감사위원회
# 2022.02.08
# ㆍ
# 제1호 의안 : 내부회계관리제도 운영실태 보고의 건
# -
# 참석
# 참석
# 참석
# ㆍ
# 제2호 의안 : 제61기 재무제표(별도

# %%
a = pd.read_csv('C:\파이썬\data\사업보고서_CSV_통합\통합_사업보고서 (2022-2024).csv')
hyundai = a[a['회사명']=='SK하이닉스']
hyundai
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\iamkk\AppData\Local\Temp\ipykernel_30200\764828560.py:1: SyntaxWarning: invalid escape sequence '\d'
#   a = pd.read_csv('C:\파이썬\data\사업보고서_CSV_통합\통합_사업보고서 (2022-2024).csv')
#      년도     회사명                                           텍스트 미리보기
# 4  2021  SK하이닉스  연결감사보고서\n3.4\n에스케이하이닉스주식회사\n00260295\n10000000...
# 5  2022  SK하이닉스  분기보고서\n4.8\nSK하이닉스\n분 기 보 고 서\n&cr;&cr;&cr;\n(...
# 6  2023  SK하이닉스  분기보고서\n5.0\nSK하이닉스\n분 기 보 고 서\n(제 76 기)\n사업연도\...
# 7  2024  SK하이닉스  분기보고서\n5.6\nSK하이닉스\n1\nY\n분 기 보 고 서\n(제 77 기)\...
