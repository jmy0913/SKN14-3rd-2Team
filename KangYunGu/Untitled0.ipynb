# %%
# %pip install langchain langchain-openai langchain-pinecone
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 kB 695.2 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.3/46.3 kB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.6/587.6 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.0/240.0 kB 11.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.2/52.2 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221.1/221.1 kB 9.5 MB/s eta 0:00:00
# ...

# %%
from pinecone import Pinecone

# Pinecone 인스턴스 생성
pc = Pinecone(
    api_key="pcsk_4e6ksU_3nTxzH3UP6NdGqh3LTNCPakpQyGw8ZVCmCuSnSQdAUgVgETxqykbGnueMaQBiad"
)

# 인덱스 가져오기
index = pc.Index("3rd-project")

# %%
# index.describe_index_stats()로 벡터 수 확인
stats = index.describe_index_stats()
print(stats)

# 특정 범위의 벡터 ID 목록 확인 (예: 0~99)
ids = [f"chunk_{i}" for i in range(100)]  # ID 규칙에 맞게 수정
results = index.fetch(ids=ids)
print(results)
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.0,
#  'metric': 'cosine',
#  'namespaces': {'': {'vector_count': 3626}},
#  'total_vector_count': 3626,
#  'vector_type': 'dense'}
# FetchResponse(namespace='', vectors={}, usage={})
